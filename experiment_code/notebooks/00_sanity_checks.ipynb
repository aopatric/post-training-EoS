# %% [markdown]
# # Some Sanity Checks for Components of the Project
#
# Some of these components require their own sense of testing, dumping their sanity checks here! First getting file setup right:

# %%
import sys; sys.path.append("../src")

# %% [markdown]
# ### Synthetic Data Gen
#
# Dry run for generating dataset:

# %%
from arithmetic import generate_arithmetic_dataset, PROBLEM_TYPES
from pathlib import Path

generate_arithmetic_dataset(
    output_dir=Path("../src/data/"),
    problem_types=PROBLEM_TYPES,
)
# Out:
# Generating two_digit_division samples...: 100%|██████████| 8/8 [00:00<00:00, 275.90it/s]
# Dataset saved to ../src/data/arithmetic_data.jsonl
# [{'input': 'What is 78 - 17?',
#   'target': 61,
#   'metadata': {'x': 78, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 49?',
#   'target': 19,
#   'metadata': {'x': 68, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 48?',
#   'target': 38,
#   'metadata': {'x': 86, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 17?',
#   'target': 55,
#   'metadata': {'x': 72, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 27 - 18?',
#   'target': 9,
#   'metadata': {'x': 27, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 56?',
#   'target': 40,
#   'metadata': {'x': 96, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 75?',
#   'target': 2,
#   'metadata': {'x': 77, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 73?',
#   'target': 6,
#   'metadata': {'x': 79, 'y': 73, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 55 - 21?',
#   'target': 34,
#   'metadata': {'x': 55, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 50?',
#   'target': 34,
#   'metadata': {'x': 84, 'y': 50, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 43?',
#   'target': 11,
#   'metadata': {'x': 54, 'y': 43, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 26?',
#   'target': 66,
#   'metadata': {'x': 92, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 67?',
#   'target': 12,
#   'metadata': {'x': 79, 'y': 67, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 45?',
#   'target': 38,
#   'metadata': {'x': 83, 'y': 45, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 49?',
#   'target': 9,
#   'metadata': {'x': 58, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 30?',
#   'target': 20,
#   'metadata': {'x': 50, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 18?',
#   'target': 41,
#   'metadata': {'x': 59, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 15?',
#   'target': 74,
#   'metadata': {'x': 89, 'y': 15, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 83?',
#   'target': 3,
#   'metadata': {'x': 86, 'y': 83, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 34?',
#   'target': 32,
#   'metadata': {'x': 66, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 24?',
#   'target': 53,
#   'metadata': {'x': 77, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 41?',
#   'target': 31,
#   'metadata': {'x': 72, 'y': 41, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 16?',
#   'target': 80,
#   'metadata': {'x': 96, 'y': 16, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 49?',
#   'target': 40,
#   'metadata': {'x': 89, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 70?',
#   'target': 9,
#   'metadata': {'x': 79, 'y': 70, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 27?',
#   'target': 50,
#   'metadata': {'x': 77, 'y': 27, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 42?',
#   'target': 9,
#   'metadata': {'x': 51, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 13?',
#   'target': 41,
#   'metadata': {'x': 54, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 23?',
#   'target': 35,
#   'metadata': {'x': 58, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 76 - 70?',
#   'target': 6,
#   'metadata': {'x': 76, 'y': 70, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 76?',
#   'target': 16,
#   'metadata': {'x': 92, 'y': 76, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 42?',
#   'target': 54,
#   'metadata': {'x': 96, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 46 - 38?',
#   'target': 8,
#   'metadata': {'x': 46, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 42?',
#   'target': 48,
#   'metadata': {'x': 90, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 16?',
#   'target': 35,
#   'metadata': {'x': 51, 'y': 16, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 26?',
#   'target': 54,
#   'metadata': {'x': 80, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 21?',
#   'target': 30,
#   'metadata': {'x': 51, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 52?',
#   'target': 19,
#   'metadata': {'x': 71, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 39 - 30?',
#   'target': 9,
#   'metadata': {'x': 39, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 60?',
#   'target': 9,
#   'metadata': {'x': 69, 'y': 60, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 48?',
#   'target': 45,
#   'metadata': {'x': 93, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 24?',
#   'target': 60,
#   'metadata': {'x': 84, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 66?',
#   'target': 6,
#   'metadata': {'x': 72, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 37 - 18?',
#   'target': 19,
#   'metadata': {'x': 37, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 78?',
#   'target': 6,
#   'metadata': {'x': 84, 'y': 78, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 48?',
#   'target': 33,
#   'metadata': {'x': 81, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 44?',
#   'target': 40,
#   'metadata': {'x': 84, 'y': 44, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 35?',
#   'target': 54,
#   'metadata': {'x': 89, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 31?',
#   'target': 39,
#   'metadata': {'x': 70, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 22?',
#   'target': 44,
#   'metadata': {'x': 66, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 27?',
#   'target': 57,
#   'metadata': {'x': 84, 'y': 27, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 10?',
#   'target': 71,
#   'metadata': {'x': 81, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 80?',
#   'target': 0,
#   'metadata': {'x': 80, 'y': 80, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 69?',
#   'target': 10,
#   'metadata': {'x': 79, 'y': 69, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 51?',
#   'target': 21,
#   'metadata': {'x': 72, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 34?',
#   'target': 45,
#   'metadata': {'x': 79, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 50?',
#   'target': 9,
#   'metadata': {'x': 59, 'y': 50, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 60 - 54?',
#   'target': 6,
#   'metadata': {'x': 60, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 22 - 13?',
#   'target': 9,
#   'metadata': {'x': 22, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 31 - 20?',
#   'target': 11,
#   'metadata': {'x': 31, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 49?',
#   'target': 20,
#   'metadata': {'x': 69, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 51?',
#   'target': 17,
#   'metadata': {'x': 68, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 60?',
#   'target': 26,
#   'metadata': {'x': 86, 'y': 60, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 17?',
#   'target': 61,
#   'metadata': {'x': 78, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 61?',
#   'target': 5,
#   'metadata': {'x': 66, 'y': 61, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 60 - 59?',
#   'target': 1,
#   'metadata': {'x': 60, 'y': 59, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 18?',
#   'target': 41,
#   'metadata': {'x': 59, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 37?',
#   'target': 43,
#   'metadata': {'x': 80, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 12?',
#   'target': 51,
#   'metadata': {'x': 63, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 40?',
#   'target': 8,
#   'metadata': {'x': 48, 'y': 40, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 97 - 29?',
#   'target': 68,
#   'metadata': {'x': 97, 'y': 29, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 46 - 34?',
#   'target': 12,
#   'metadata': {'x': 46, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 85?',
#   'target': 13,
#   'metadata': {'x': 98, 'y': 85, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 30 - 13?',
#   'target': 17,
#   'metadata': {'x': 30, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 15?',
#   'target': 68,
#   'metadata': {'x': 83, 'y': 15, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 35?',
#   'target': 51,
#   'metadata': {'x': 86, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 36?',
#   'target': 55,
#   'metadata': {'x': 91, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 48?',
#   'target': 20,
#   'metadata': {'x': 68, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 21?',
#   'target': 38,
#   'metadata': {'x': 59, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 54?',
#   'target': 25,
#   'metadata': {'x': 79, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 69?',
#   'target': 29,
#   'metadata': {'x': 98, 'y': 69, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 46 - 46?',
#   'target': 0,
#   'metadata': {'x': 46, 'y': 46, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 82 - 47?',
#   'target': 35,
#   'metadata': {'x': 82, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 38 - 24?',
#   'target': 14,
#   'metadata': {'x': 38, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 39 - 12?',
#   'target': 27,
#   'metadata': {'x': 39, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 19 - 18?',
#   'target': 1,
#   'metadata': {'x': 19, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 74?',
#   'target': 4,
#   'metadata': {'x': 78, 'y': 74, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 51?',
#   'target': 21,
#   'metadata': {'x': 72, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 73 - 24?',
#   'target': 49,
#   'metadata': {'x': 73, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 54?',
#   'target': 36,
#   'metadata': {'x': 90, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 23?',
#   'target': 70,
#   'metadata': {'x': 93, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 54?',
#   'target': 17,
#   'metadata': {'x': 71, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 49?',
#   'target': 5,
#   'metadata': {'x': 54, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 43 - 24?',
#   'target': 19,
#   'metadata': {'x': 43, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 36 - 31?',
#   'target': 5,
#   'metadata': {'x': 36, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 66?',
#   'target': 4,
#   'metadata': {'x': 70, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 64 - 42?',
#   'target': 22,
#   'metadata': {'x': 64, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 17?',
#   'target': 78,
#   'metadata': {'x': 95, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 40 - 20?',
#   'target': 20,
#   'metadata': {'x': 40, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 40?',
#   'target': 55,
#   'metadata': {'x': 95, 'y': 40, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 42?',
#   'target': 48,
#   'metadata': {'x': 90, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 54?',
#   'target': 18,
#   'metadata': {'x': 72, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 33?',
#   'target': 17,
#   'metadata': {'x': 50, 'y': 33, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 78?',
#   'target': 18,
#   'metadata': {'x': 96, 'y': 78, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 33?',
#   'target': 46,
#   'metadata': {'x': 79, 'y': 33, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 73 - 33?',
#   'target': 40,
#   'metadata': {'x': 73, 'y': 33, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 49?',
#   'target': 31,
#   'metadata': {'x': 80, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 34?',
#   'target': 41,
#   'metadata': {'x': 75, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 18 - 17?',
#   'target': 1,
#   'metadata': {'x': 18, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 49?',
#   'target': 41,
#   'metadata': {'x': 90, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 21?',
#   'target': 29,
#   'metadata': {'x': 50, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 72 - 28?',
#   'target': 44,
#   'metadata': {'x': 72, 'y': 28, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 37?',
#   'target': 37,
#   'metadata': {'x': 74, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 61?',
#   'target': 20,
#   'metadata': {'x': 81, 'y': 61, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 25?',
#   'target': 33,
#   'metadata': {'x': 58, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 51?',
#   'target': 35,
#   'metadata': {'x': 86, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 11?',
#   'target': 66,
#   'metadata': {'x': 77, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 53?',
#   'target': 21,
#   'metadata': {'x': 74, 'y': 53, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 48?',
#   'target': 21,
#   'metadata': {'x': 69, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 65 - 37?',
#   'target': 28,
#   'metadata': {'x': 65, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 61 - 22?',
#   'target': 39,
#   'metadata': {'x': 61, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 67 - 18?',
#   'target': 49,
#   'metadata': {'x': 67, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 65 - 17?',
#   'target': 48,
#   'metadata': {'x': 65, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 47?',
#   'target': 30,
#   'metadata': {'x': 77, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 13?',
#   'target': 67,
#   'metadata': {'x': 80, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 53 - 25?',
#   'target': 28,
#   'metadata': {'x': 53, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 39 - 26?',
#   'target': 13,
#   'metadata': {'x': 39, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 22?',
#   'target': 46,
#   'metadata': {'x': 68, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 19?',
#   'target': 51,
#   'metadata': {'x': 70, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 62 - 25?',
#   'target': 37,
#   'metadata': {'x': 62, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 25?',
#   'target': 55,
#   'metadata': {'x': 80, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 36?',
#   'target': 56,
#   'metadata': {'x': 92, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 61?',
#   'target': 37,
#   'metadata': {'x': 98, 'y': 61, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 49 - 40?',
#   'target': 9,
#   'metadata': {'x': 49, 'y': 40, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 64 - 62?',
#   'target': 2,
#   'metadata': {'x': 64, 'y': 62, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 36 - 12?',
#   'target': 24,
#   'metadata': {'x': 36, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 23?',
#   'target': 72,
#   'metadata': {'x': 95, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 52 - 47?',
#   'target': 5,
#   'metadata': {'x': 52, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 51?',
#   'target': 28,
#   'metadata': {'x': 79, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 17 - 15?',
#   'target': 2,
#   'metadata': {'x': 17, 'y': 15, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 53 - 34?',
#   'target': 19,
#   'metadata': {'x': 53, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 53?',
#   'target': 16,
#   'metadata': {'x': 69, 'y': 53, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 49?',
#   'target': 44,
#   'metadata': {'x': 93, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 60 - 24?',
#   'target': 36,
#   'metadata': {'x': 60, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 52?',
#   'target': 6,
#   'metadata': {'x': 58, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 33?',
#   'target': 48,
#   'metadata': {'x': 81, 'y': 33, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 39?',
#   'target': 55,
#   'metadata': {'x': 94, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 56?',
#   'target': 2,
#   'metadata': {'x': 58, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 49?',
#   'target': 36,
#   'metadata': {'x': 85, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 35 - 11?',
#   'target': 24,
#   'metadata': {'x': 35, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 42?',
#   'target': 41,
#   'metadata': {'x': 83, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 10?',
#   'target': 79,
#   'metadata': {'x': 89, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 22?',
#   'target': 36,
#   'metadata': {'x': 58, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 36?',
#   'target': 23,
#   'metadata': {'x': 59, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 38 - 19?',
#   'target': 19,
#   'metadata': {'x': 38, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 69?',
#   'target': 0,
#   'metadata': {'x': 69, 'y': 69, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 35 - 20?',
#   'target': 15,
#   'metadata': {'x': 35, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 31?',
#   'target': 37,
#   'metadata': {'x': 68, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 74?',
#   'target': 0,
#   'metadata': {'x': 74, 'y': 74, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 78?',
#   'target': 15,
#   'metadata': {'x': 93, 'y': 78, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 38 - 19?',
#   'target': 19,
#   'metadata': {'x': 38, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 64?',
#   'target': 27,
#   'metadata': {'x': 91, 'y': 64, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 30?',
#   'target': 66,
#   'metadata': {'x': 96, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 31 - 13?',
#   'target': 18,
#   'metadata': {'x': 31, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 22?',
#   'target': 37,
#   'metadata': {'x': 59, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 43?',
#   'target': 15,
#   'metadata': {'x': 58, 'y': 43, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 37?',
#   'target': 46,
#   'metadata': {'x': 83, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 50?',
#   'target': 31,
#   'metadata': {'x': 81, 'y': 50, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 38?',
#   'target': 57,
#   'metadata': {'x': 95, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 28?',
#   'target': 66,
#   'metadata': {'x': 94, 'y': 28, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 35?',
#   'target': 31,
#   'metadata': {'x': 66, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 65 - 55?',
#   'target': 10,
#   'metadata': {'x': 65, 'y': 55, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 32?',
#   'target': 58,
#   'metadata': {'x': 90, 'y': 32, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 93?',
#   'target': 5,
#   'metadata': {'x': 98, 'y': 93, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 26 - 24?',
#   'target': 2,
#   'metadata': {'x': 26, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 13?',
#   'target': 44,
#   'metadata': {'x': 57, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 36?',
#   'target': 12,
#   'metadata': {'x': 48, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 96?',
#   'target': 2,
#   'metadata': {'x': 98, 'y': 96, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 23?',
#   'target': 66,
#   'metadata': {'x': 89, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 76 - 18?',
#   'target': 58,
#   'metadata': {'x': 76, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 85?',
#   'target': 4,
#   'metadata': {'x': 89, 'y': 85, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 29?',
#   'target': 60,
#   'metadata': {'x': 89, 'y': 29, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 56 - 20?',
#   'target': 36,
#   'metadata': {'x': 56, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 38?',
#   'target': 13,
#   'metadata': {'x': 51, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 11?',
#   'target': 67,
#   'metadata': {'x': 78, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 39?',
#   'target': 29,
#   'metadata': {'x': 68, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 46 - 43?',
#   'target': 3,
#   'metadata': {'x': 46, 'y': 43, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 88 - 18?',
#   'target': 70,
#   'metadata': {'x': 88, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 76 - 75?',
#   'target': 1,
#   'metadata': {'x': 76, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 43 - 33?',
#   'target': 10,
#   'metadata': {'x': 43, 'y': 33, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 10?',
#   'target': 83,
#   'metadata': {'x': 93, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 31?',
#   'target': 63,
#   'metadata': {'x': 94, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 20 - 12?',
#   'target': 8,
#   'metadata': {'x': 20, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 16?',
#   'target': 67,
#   'metadata': {'x': 83, 'y': 16, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 23?',
#   'target': 66,
#   'metadata': {'x': 89, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 76 - 25?',
#   'target': 51,
#   'metadata': {'x': 76, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 42?',
#   'target': 21,
#   'metadata': {'x': 63, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 87 - 74?',
#   'target': 13,
#   'metadata': {'x': 87, 'y': 74, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 27 - 13?',
#   'target': 14,
#   'metadata': {'x': 27, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 37 - 34?',
#   'target': 3,
#   'metadata': {'x': 37, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 79?',
#   'target': 19,
#   'metadata': {'x': 98, 'y': 79, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 38?',
#   'target': 58,
#   'metadata': {'x': 96, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 54?',
#   'target': 0,
#   'metadata': {'x': 54, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 22?',
#   'target': 26,
#   'metadata': {'x': 48, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 11?',
#   'target': 82,
#   'metadata': {'x': 93, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 30 - 25?',
#   'target': 5,
#   'metadata': {'x': 30, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 34 - 21?',
#   'target': 13,
#   'metadata': {'x': 34, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 11?',
#   'target': 59,
#   'metadata': {'x': 70, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 20?',
#   'target': 76,
#   'metadata': {'x': 96, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 55 - 36?',
#   'target': 19,
#   'metadata': {'x': 55, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 71?',
#   'target': 21,
#   'metadata': {'x': 92, 'y': 71, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 61?',
#   'target': 17,
#   'metadata': {'x': 78, 'y': 61, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 47 - 27?',
#   'target': 20,
#   'metadata': {'x': 47, 'y': 27, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 81?',
#   'target': 5,
#   'metadata': {'x': 86, 'y': 81, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 73 - 12?',
#   'target': 61,
#   'metadata': {'x': 73, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 17?',
#   'target': 58,
#   'metadata': {'x': 75, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 21?',
#   'target': 62,
#   'metadata': {'x': 83, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 21?',
#   'target': 27,
#   'metadata': {'x': 48, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 60?',
#   'target': 32,
#   'metadata': {'x': 92, 'y': 60, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 45 - 17?',
#   'target': 28,
#   'metadata': {'x': 45, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 36?',
#   'target': 60,
#   'metadata': {'x': 96, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 53 - 21?',
#   'target': 32,
#   'metadata': {'x': 53, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 55?',
#   'target': 13,
#   'metadata': {'x': 68, 'y': 55, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 37?',
#   'target': 58,
#   'metadata': {'x': 95, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 56 - 35?',
#   'target': 21,
#   'metadata': {'x': 56, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 92?',
#   'target': 3,
#   'metadata': {'x': 95, 'y': 92, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 12?',
#   'target': 42,
#   'metadata': {'x': 54, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 59?',
#   'target': 4,
#   'metadata': {'x': 63, 'y': 59, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 23?',
#   'target': 43,
#   'metadata': {'x': 66, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 19?',
#   'target': 65,
#   'metadata': {'x': 84, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 22?',
#   'target': 52,
#   'metadata': {'x': 74, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 76 - 47?',
#   'target': 29,
#   'metadata': {'x': 76, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 10?',
#   'target': 85,
#   'metadata': {'x': 95, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 24?',
#   'target': 39,
#   'metadata': {'x': 63, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 26?',
#   'target': 67,
#   'metadata': {'x': 93, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 75?',
#   'target': 6,
#   'metadata': {'x': 81, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 48?',
#   'target': 3,
#   'metadata': {'x': 51, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 66?',
#   'target': 13,
#   'metadata': {'x': 79, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 11?',
#   'target': 74,
#   'metadata': {'x': 85, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 19?',
#   'target': 50,
#   'metadata': {'x': 69, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 35?',
#   'target': 48,
#   'metadata': {'x': 83, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 32?',
#   'target': 48,
#   'metadata': {'x': 80, 'y': 32, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 51 - 30?',
#   'target': 21,
#   'metadata': {'x': 51, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 39?',
#   'target': 18,
#   'metadata': {'x': 57, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 63?',
#   'target': 15,
#   'metadata': {'x': 78, 'y': 63, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 87?',
#   'target': 6,
#   'metadata': {'x': 93, 'y': 87, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 63?',
#   'target': 14,
#   'metadata': {'x': 77, 'y': 63, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 46 - 35?',
#   'target': 11,
#   'metadata': {'x': 46, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 43 - 20?',
#   'target': 23,
#   'metadata': {'x': 43, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 47?',
#   'target': 45,
#   'metadata': {'x': 92, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 20?',
#   'target': 48,
#   'metadata': {'x': 68, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 87?',
#   'target': 8,
#   'metadata': {'x': 95, 'y': 87, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 34?',
#   'target': 16,
#   'metadata': {'x': 50, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 32?',
#   'target': 25,
#   'metadata': {'x': 57, 'y': 32, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 33 - 31?',
#   'target': 2,
#   'metadata': {'x': 33, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 76?',
#   'target': 22,
#   'metadata': {'x': 98, 'y': 76, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 82?',
#   'target': 2,
#   'metadata': {'x': 84, 'y': 82, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 19?',
#   'target': 76,
#   'metadata': {'x': 95, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 88 - 15?',
#   'target': 73,
#   'metadata': {'x': 88, 'y': 15, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 62 - 52?',
#   'target': 10,
#   'metadata': {'x': 62, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 41 - 23?',
#   'target': 18,
#   'metadata': {'x': 41, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 27?',
#   'target': 56,
#   'metadata': {'x': 83, 'y': 27, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 38 - 37?',
#   'target': 1,
#   'metadata': {'x': 38, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 22?',
#   'target': 70,
#   'metadata': {'x': 92, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 91?',
#   'target': 0,
#   'metadata': {'x': 91, 'y': 91, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 24?',
#   'target': 39,
#   'metadata': {'x': 63, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 35 - 23?',
#   'target': 12,
#   'metadata': {'x': 35, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 61 - 23?',
#   'target': 38,
#   'metadata': {'x': 61, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 20?',
#   'target': 30,
#   'metadata': {'x': 50, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 11?',
#   'target': 47,
#   'metadata': {'x': 58, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 73 - 14?',
#   'target': 59,
#   'metadata': {'x': 73, 'y': 14, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 27 - 25?',
#   'target': 2,
#   'metadata': {'x': 27, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 14?',
#   'target': 69,
#   'metadata': {'x': 83, 'y': 14, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 62 - 48?',
#   'target': 14,
#   'metadata': {'x': 62, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 55?',
#   'target': 15,
#   'metadata': {'x': 70, 'y': 55, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 45?',
#   'target': 36,
#   'metadata': {'x': 81, 'y': 45, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 38?',
#   'target': 45,
#   'metadata': {'x': 83, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 97 - 54?',
#   'target': 43,
#   'metadata': {'x': 97, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 87 - 75?',
#   'target': 12,
#   'metadata': {'x': 87, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 80?',
#   'target': 5,
#   'metadata': {'x': 85, 'y': 80, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 13?',
#   'target': 44,
#   'metadata': {'x': 57, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 53 - 26?',
#   'target': 27,
#   'metadata': {'x': 53, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 31?',
#   'target': 58,
#   'metadata': {'x': 89, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 32 - 30?',
#   'target': 2,
#   'metadata': {'x': 32, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 67 - 60?',
#   'target': 7,
#   'metadata': {'x': 67, 'y': 60, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 47?',
#   'target': 47,
#   'metadata': {'x': 94, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 35 - 14?',
#   'target': 21,
#   'metadata': {'x': 35, 'y': 14, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 43 - 10?',
#   'target': 33,
#   'metadata': {'x': 43, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 56?',
#   'target': 36,
#   'metadata': {'x': 92, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 19?',
#   'target': 70,
#   'metadata': {'x': 89, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 18?',
#   'target': 66,
#   'metadata': {'x': 84, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 19 - 14?',
#   'target': 5,
#   'metadata': {'x': 19, 'y': 14, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 45?',
#   'target': 47,
#   'metadata': {'x': 92, 'y': 45, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 18?',
#   'target': 53,
#   'metadata': {'x': 71, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 84?',
#   'target': 1,
#   'metadata': {'x': 85, 'y': 84, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 90 - 81?',
#   'target': 9,
#   'metadata': {'x': 90, 'y': 81, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 97 - 31?',
#   'target': 66,
#   'metadata': {'x': 97, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 38?',
#   'target': 43,
#   'metadata': {'x': 81, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 61?',
#   'target': 18,
#   'metadata': {'x': 79, 'y': 61, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 67 - 65?',
#   'target': 2,
#   'metadata': {'x': 67, 'y': 65, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 64?',
#   'target': 15,
#   'metadata': {'x': 79, 'y': 64, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 21?',
#   'target': 54,
#   'metadata': {'x': 75, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 57?',
#   'target': 26,
#   'metadata': {'x': 83, 'y': 57, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 55 - 38?',
#   'target': 17,
#   'metadata': {'x': 55, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 86?',
#   'target': 10,
#   'metadata': {'x': 96, 'y': 86, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 51?',
#   'target': 33,
#   'metadata': {'x': 84, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 44?',
#   'target': 35,
#   'metadata': {'x': 79, 'y': 44, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 66?',
#   'target': 5,
#   'metadata': {'x': 71, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 33 - 32?',
#   'target': 1,
#   'metadata': {'x': 33, 'y': 32, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 22 - 15?',
#   'target': 7,
#   'metadata': {'x': 22, 'y': 15, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 52 - 48?',
#   'target': 4,
#   'metadata': {'x': 52, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 47 - 24?',
#   'target': 23,
#   'metadata': {'x': 47, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 30?',
#   'target': 33,
#   'metadata': {'x': 63, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 42 - 40?',
#   'target': 2,
#   'metadata': {'x': 42, 'y': 40, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 54 - 42?',
#   'target': 12,
#   'metadata': {'x': 54, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 39?',
#   'target': 36,
#   'metadata': {'x': 75, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 43?',
#   'target': 5,
#   'metadata': {'x': 48, 'y': 43, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 26?',
#   'target': 45,
#   'metadata': {'x': 71, 'y': 26, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 36 - 30?',
#   'target': 6,
#   'metadata': {'x': 36, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 80?',
#   'target': 14,
#   'metadata': {'x': 94, 'y': 80, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 69?',
#   'target': 22,
#   'metadata': {'x': 91, 'y': 69, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 52?',
#   'target': 34,
#   'metadata': {'x': 86, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 39?',
#   'target': 39,
#   'metadata': {'x': 78, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 50?',
#   'target': 7,
#   'metadata': {'x': 57, 'y': 50, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 85?',
#   'target': 10,
#   'metadata': {'x': 95, 'y': 85, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 53?',
#   'target': 15,
#   'metadata': {'x': 68, 'y': 53, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 28?',
#   'target': 53,
#   'metadata': {'x': 81, 'y': 28, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 57?',
#   'target': 2,
#   'metadata': {'x': 59, 'y': 57, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 78 - 66?',
#   'target': 12,
#   'metadata': {'x': 78, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 35 - 16?',
#   'target': 19,
#   'metadata': {'x': 35, 'y': 16, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 25?',
#   'target': 50,
#   'metadata': {'x': 75, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 28 - 13?',
#   'target': 15,
#   'metadata': {'x': 28, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 63?',
#   'target': 8,
#   'metadata': {'x': 71, 'y': 63, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 54?',
#   'target': 32,
#   'metadata': {'x': 86, 'y': 54, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 21?',
#   'target': 70,
#   'metadata': {'x': 91, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 64?',
#   'target': 30,
#   'metadata': {'x': 94, 'y': 64, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 18?',
#   'target': 48,
#   'metadata': {'x': 66, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 65?',
#   'target': 9,
#   'metadata': {'x': 74, 'y': 65, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 61 - 17?',
#   'target': 44,
#   'metadata': {'x': 61, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 56?',
#   'target': 37,
#   'metadata': {'x': 93, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 22?',
#   'target': 52,
#   'metadata': {'x': 74, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 95?',
#   'target': 0,
#   'metadata': {'x': 95, 'y': 95, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 81 - 25?',
#   'target': 56,
#   'metadata': {'x': 81, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 62 - 46?',
#   'target': 16,
#   'metadata': {'x': 62, 'y': 46, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 49?',
#   'target': 30,
#   'metadata': {'x': 79, 'y': 49, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 80?',
#   'target': 18,
#   'metadata': {'x': 98, 'y': 80, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 92?',
#   'target': 2,
#   'metadata': {'x': 94, 'y': 92, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 32 - 18?',
#   'target': 14,
#   'metadata': {'x': 32, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 62?',
#   'target': 12,
#   'metadata': {'x': 74, 'y': 62, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 18 - 14?',
#   'target': 4,
#   'metadata': {'x': 18, 'y': 14, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 64 - 56?',
#   'target': 8,
#   'metadata': {'x': 64, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 25 - 24?',
#   'target': 1,
#   'metadata': {'x': 25, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 60 - 21?',
#   'target': 39,
#   'metadata': {'x': 60, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 60 - 10?',
#   'target': 50,
#   'metadata': {'x': 60, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 52 - 51?',
#   'target': 1,
#   'metadata': {'x': 52, 'y': 51, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 56?',
#   'target': 14,
#   'metadata': {'x': 70, 'y': 56, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 77 - 74?',
#   'target': 3,
#   'metadata': {'x': 77, 'y': 74, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 81?',
#   'target': 10,
#   'metadata': {'x': 91, 'y': 81, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 56 - 53?',
#   'target': 3,
#   'metadata': {'x': 56, 'y': 53, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 63 - 30?',
#   'target': 33,
#   'metadata': {'x': 63, 'y': 30, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 22?',
#   'target': 70,
#   'metadata': {'x': 92, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 20?',
#   'target': 65,
#   'metadata': {'x': 85, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 20?',
#   'target': 59,
#   'metadata': {'x': 79, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 17?',
#   'target': 57,
#   'metadata': {'x': 74, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 68 - 53?',
#   'target': 15,
#   'metadata': {'x': 68, 'y': 53, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 47?',
#   'target': 27,
#   'metadata': {'x': 74, 'y': 47, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 92 - 78?',
#   'target': 14,
#   'metadata': {'x': 92, 'y': 78, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 28?',
#   'target': 41,
#   'metadata': {'x': 69, 'y': 28, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 39?',
#   'target': 36,
#   'metadata': {'x': 75, 'y': 39, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 75?',
#   'target': 14,
#   'metadata': {'x': 89, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 82 - 77?',
#   'target': 5,
#   'metadata': {'x': 82, 'y': 77, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 66 - 34?',
#   'target': 32,
#   'metadata': {'x': 66, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 80 - 42?',
#   'target': 38,
#   'metadata': {'x': 80, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 57 - 37?',
#   'target': 20,
#   'metadata': {'x': 57, 'y': 37, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 37 - 24?',
#   'target': 13,
#   'metadata': {'x': 37, 'y': 24, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 95 - 23?',
#   'target': 72,
#   'metadata': {'x': 95, 'y': 23, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 93 - 17?',
#   'target': 76,
#   'metadata': {'x': 93, 'y': 17, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 48?',
#   'target': 11,
#   'metadata': {'x': 59, 'y': 48, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 75 - 44?',
#   'target': 31,
#   'metadata': {'x': 75, 'y': 44, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 74 - 21?',
#   'target': 53,
#   'metadata': {'x': 74, 'y': 21, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 59 - 25?',
#   'target': 34,
#   'metadata': {'x': 59, 'y': 25, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 93?',
#   'target': 1,
#   'metadata': {'x': 94, 'y': 93, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 42?',
#   'target': 37,
#   'metadata': {'x': 79, 'y': 42, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 64 - 52?',
#   'target': 12,
#   'metadata': {'x': 64, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 43 - 22?',
#   'target': 21,
#   'metadata': {'x': 43, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 97 - 68?',
#   'target': 29,
#   'metadata': {'x': 97, 'y': 68, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 73 - 10?',
#   'target': 63,
#   'metadata': {'x': 73, 'y': 10, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 94 - 85?',
#   'target': 9,
#   'metadata': {'x': 94, 'y': 85, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 47 - 20?',
#   'target': 27,
#   'metadata': {'x': 47, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 85 - 34?',
#   'target': 51,
#   'metadata': {'x': 85, 'y': 34, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 88 - 66?',
#   'target': 22,
#   'metadata': {'x': 88, 'y': 66, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 20 - 20?',
#   'target': 0,
#   'metadata': {'x': 20, 'y': 20, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 62 - 52?',
#   'target': 10,
#   'metadata': {'x': 62, 'y': 52, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 71 - 12?',
#   'target': 59,
#   'metadata': {'x': 71, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 11?',
#   'target': 47,
#   'metadata': {'x': 58, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 18?',
#   'target': 32,
#   'metadata': {'x': 50, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 83 - 74?',
#   'target': 9,
#   'metadata': {'x': 83, 'y': 74, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 48 - 36?',
#   'target': 12,
#   'metadata': {'x': 48, 'y': 36, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 96 - 50?',
#   'target': 46,
#   'metadata': {'x': 96, 'y': 50, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 49 - 38?',
#   'target': 11,
#   'metadata': {'x': 49, 'y': 38, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 36 - 11?',
#   'target': 25,
#   'metadata': {'x': 36, 'y': 11, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 91 - 55?',
#   'target': 36,
#   'metadata': {'x': 91, 'y': 55, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 79 - 75?',
#   'target': 4,
#   'metadata': {'x': 79, 'y': 75, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 58 - 19?',
#   'target': 39,
#   'metadata': {'x': 58, 'y': 19, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 44?',
#   'target': 54,
#   'metadata': {'x': 98, 'y': 44, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 88 - 13?',
#   'target': 75,
#   'metadata': {'x': 88, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 70 - 35?',
#   'target': 35,
#   'metadata': {'x': 70, 'y': 35, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 84 - 79?',
#   'target': 5,
#   'metadata': {'x': 84, 'y': 79, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 19 - 13?',
#   'target': 6,
#   'metadata': {'x': 19, 'y': 13, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 98 - 69?',
#   'target': 29,
#   'metadata': {'x': 98, 'y': 69, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 69 - 12?',
#   'target': 57,
#   'metadata': {'x': 69, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 67 - 22?',
#   'target': 45,
#   'metadata': {'x': 67, 'y': 22, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 65 - 18?',
#   'target': 47,
#   'metadata': {'x': 65, 'y': 18, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 89 - 70?',
#   'target': 19,
#   'metadata': {'x': 89, 'y': 70, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 86 - 12?',
#   'target': 74,
#   'metadata': {'x': 86, 'y': 12, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 31 - 31?',
#   'target': 0,
#   'metadata': {'x': 31, 'y': 31, 'type': 'two_digit_subtraction'}},
#  {'input': 'What is 50 - 22?',
#   'target': 28,
# ...
#  {'input': 'What is 56 + 53?',
#   'target': 109,
#   'metadata': {'x': 56, 'y': 53, 'type': 'two_digit_addition'}},
#  {'input': 'What is 30 + 63?',
#   'target': 93,
#   'metadata': {'x': 30, 'y': 63, 'type': 'two_digit_addition'}},
#  {'input': 'What is 22 + 92?',
#   'target': 114,
#   'metadata': {'x': 22, 'y': 92, 'type': 'two_digit_addition'}},
#  {'input': 'What is 85 + 20?',
#   'target': 105,
#   'metadata': {'x': 85, 'y': 20, 'type': 'two_digit_addition'}},
#  {'input': 'What is 79 + 20?',
#   'target': 99,
#   'metadata': {'x': 79, 'y': 20, 'type': 'two_digit_addition'}},
#  {'input': 'What is 74 + 17?',
#   'target': 91,
#   'metadata': {'x': 74, 'y': 17, 'type': 'two_digit_addition'}},
#  {'input': 'What is 53 + 68?',
#   'target': 121,
#   'metadata': {'x': 53, 'y': 68, 'type': 'two_digit_addition'}},
#  {'input': 'What is 74 + 47?',
#   'target': 121,
#   'metadata': {'x': 74, 'y': 47, 'type': 'two_digit_addition'}},
#  {'input': 'What is 92 + 78?',
#   'target': 170,
#   'metadata': {'x': 92, 'y': 78, 'type': 'two_digit_addition'}},
#  {'input': 'What is 28 + 69?',
#   'target': 97,
#   'metadata': {'x': 28, 'y': 69, 'type': 'two_digit_addition'}},
#  {'input': 'What is 75 + 39?',
#   'target': 114,
#   'metadata': {'x': 75, 'y': 39, 'type': 'two_digit_addition'}},
#  {'input': 'What is 75 + 89?',
#   'target': 164,
#   'metadata': {'x': 75, 'y': 89, 'type': 'two_digit_addition'}},
#  {'input': 'What is 82 + 77?',
#   'target': 159,
#   'metadata': {'x': 82, 'y': 77, 'type': 'two_digit_addition'}},
#  {'input': 'What is 66 + 34?',
#   'target': 100,
#   'metadata': {'x': 66, 'y': 34, 'type': 'two_digit_addition'}},
#  {'input': 'What is 80 + 42?',
#   'target': 122,
#   'metadata': {'x': 80, 'y': 42, 'type': 'two_digit_addition'}},
#  {'input': 'What is 57 + 37?',
#   'target': 94,
#   'metadata': {'x': 57, 'y': 37, 'type': 'two_digit_addition'}},
#  {'input': 'What is 37 + 24?',
#   'target': 61,
#   'metadata': {'x': 37, 'y': 24, 'type': 'two_digit_addition'}},
#  {'input': 'What is 95 + 23?',
#   'target': 118,
#   'metadata': {'x': 95, 'y': 23, 'type': 'two_digit_addition'}},
#  {'input': 'What is 17 + 93?',
#   'target': 110,
#   'metadata': {'x': 17, 'y': 93, 'type': 'two_digit_addition'}},
#  {'input': 'What is 59 + 48?',
#   'target': 107,
#   'metadata': {'x': 59, 'y': 48, 'type': 'two_digit_addition'}},
#  {'input': 'What is 75 + 44?',
#   'target': 119,
#   'metadata': {'x': 75, 'y': 44, 'type': 'two_digit_addition'}},
#  {'input': 'What is 21 + 74?',
#   'target': 95,
#   'metadata': {'x': 21, 'y': 74, 'type': 'two_digit_addition'}},
#  {'input': 'What is 25 + 59?',
#   'target': 84,
#   'metadata': {'x': 25, 'y': 59, 'type': 'two_digit_addition'}},
#  {'input': 'What is 94 + 93?',
#   'target': 187,
#   'metadata': {'x': 94, 'y': 93, 'type': 'two_digit_addition'}},
#  {'input': 'What is 42 + 79?',
#   'target': 121,
#   'metadata': {'x': 42, 'y': 79, 'type': 'two_digit_addition'}},
#  {'input': 'What is 64 + 52?',
#   'target': 116,
#   'metadata': {'x': 64, 'y': 52, 'type': 'two_digit_addition'}},
#  {'input': 'What is 22 + 43?',
#   'target': 65,
#   'metadata': {'x': 22, 'y': 43, 'type': 'two_digit_addition'}},
#  {'input': 'What is 68 + 97?',
#   'target': 165,
#   'metadata': {'x': 68, 'y': 97, 'type': 'two_digit_addition'}},
#  {'input': 'What is 10 + 73?',
#   'target': 83,
#   'metadata': {'x': 10, 'y': 73, 'type': 'two_digit_addition'}},
#  {'input': 'What is 85 + 94?',
#   'target': 179,
#   'metadata': {'x': 85, 'y': 94, 'type': 'two_digit_addition'}},
#  {'input': 'What is 47 + 20?',
#   'target': 67,
#   'metadata': {'x': 47, 'y': 20, 'type': 'two_digit_addition'}},
#  {'input': 'What is 34 + 85?',
#   'target': 119,
#   'metadata': {'x': 34, 'y': 85, 'type': 'two_digit_addition'}},
#  {'input': 'What is 88 + 66?',
#   'target': 154,
#   'metadata': {'x': 88, 'y': 66, 'type': 'two_digit_addition'}},
#  {'input': 'What is 20 + 20?',
#   'target': 40,
#   'metadata': {'x': 20, 'y': 20, 'type': 'two_digit_addition'}},
#  {'input': 'What is 52 + 62?',
#   'target': 114,
#   'metadata': {'x': 52, 'y': 62, 'type': 'two_digit_addition'}},
#  {'input': 'What is 12 + 71?',
#   'target': 83,
#   'metadata': {'x': 12, 'y': 71, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 11?',
#   'target': 69,
#   'metadata': {'x': 58, 'y': 11, 'type': 'two_digit_addition'}},
#  {'input': 'What is 18 + 50?',
#   'target': 68,
#   'metadata': {'x': 18, 'y': 50, 'type': 'two_digit_addition'}},
#  {'input': 'What is 74 + 83?',
#   'target': 157,
#   'metadata': {'x': 74, 'y': 83, 'type': 'two_digit_addition'}},
#  {'input': 'What is 48 + 36?',
#   'target': 84,
#   'metadata': {'x': 48, 'y': 36, 'type': 'two_digit_addition'}},
#  {'input': 'What is 96 + 50?',
#   'target': 146,
#   'metadata': {'x': 96, 'y': 50, 'type': 'two_digit_addition'}},
#  {'input': 'What is 38 + 49?',
#   'target': 87,
#   'metadata': {'x': 38, 'y': 49, 'type': 'two_digit_addition'}},
#  {'input': 'What is 11 + 36?',
#   'target': 47,
#   'metadata': {'x': 11, 'y': 36, 'type': 'two_digit_addition'}},
#  {'input': 'What is 55 + 91?',
#   'target': 146,
#   'metadata': {'x': 55, 'y': 91, 'type': 'two_digit_addition'}},
#  {'input': 'What is 75 + 79?',
#   'target': 154,
#   'metadata': {'x': 75, 'y': 79, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 19?',
#   'target': 77,
#   'metadata': {'x': 58, 'y': 19, 'type': 'two_digit_addition'}},
#  {'input': 'What is 44 + 98?',
#   'target': 142,
#   'metadata': {'x': 44, 'y': 98, 'type': 'two_digit_addition'}},
#  {'input': 'What is 13 + 88?',
#   'target': 101,
#   'metadata': {'x': 13, 'y': 88, 'type': 'two_digit_addition'}},
#  {'input': 'What is 70 + 35?',
#   'target': 105,
#   'metadata': {'x': 70, 'y': 35, 'type': 'two_digit_addition'}},
#  {'input': 'What is 79 + 84?',
#   'target': 163,
#   'metadata': {'x': 79, 'y': 84, 'type': 'two_digit_addition'}},
#  {'input': 'What is 13 + 19?',
#   'target': 32,
#   'metadata': {'x': 13, 'y': 19, 'type': 'two_digit_addition'}},
#  {'input': 'What is 69 + 98?',
#   'target': 167,
#   'metadata': {'x': 69, 'y': 98, 'type': 'two_digit_addition'}},
#  {'input': 'What is 12 + 69?',
#   'target': 81,
#   'metadata': {'x': 12, 'y': 69, 'type': 'two_digit_addition'}},
#  {'input': 'What is 22 + 67?',
#   'target': 89,
#   'metadata': {'x': 22, 'y': 67, 'type': 'two_digit_addition'}},
#  {'input': 'What is 65 + 18?',
#   'target': 83,
#   'metadata': {'x': 65, 'y': 18, 'type': 'two_digit_addition'}},
#  {'input': 'What is 70 + 89?',
#   'target': 159,
#   'metadata': {'x': 70, 'y': 89, 'type': 'two_digit_addition'}},
#  {'input': 'What is 86 + 12?',
#   'target': 98,
#   'metadata': {'x': 86, 'y': 12, 'type': 'two_digit_addition'}},
#  {'input': 'What is 31 + 31?',
#   'target': 62,
#   'metadata': {'x': 31, 'y': 31, 'type': 'two_digit_addition'}},
#  {'input': 'What is 50 + 22?',
#   'target': 72,
#   'metadata': {'x': 50, 'y': 22, 'type': 'two_digit_addition'}},
#  {'input': 'What is 86 + 79?',
#   'target': 165,
#   'metadata': {'x': 86, 'y': 79, 'type': 'two_digit_addition'}},
#  {'input': 'What is 81 + 27?',
#   'target': 108,
#   'metadata': {'x': 81, 'y': 27, 'type': 'two_digit_addition'}},
#  {'input': 'What is 11 + 91?',
#   'target': 102,
#   'metadata': {'x': 11, 'y': 91, 'type': 'two_digit_addition'}},
#  {'input': 'What is 35 + 68?',
#   'target': 103,
#   'metadata': {'x': 35, 'y': 68, 'type': 'two_digit_addition'}},
#  {'input': 'What is 90 + 13?',
#   'target': 103,
#   'metadata': {'x': 90, 'y': 13, 'type': 'two_digit_addition'}},
#  {'input': 'What is 10 + 10?',
#   'target': 20,
#   'metadata': {'x': 10, 'y': 10, 'type': 'two_digit_addition'}},
#  {'input': 'What is 23 + 14?',
#   'target': 37,
#   'metadata': {'x': 23, 'y': 14, 'type': 'two_digit_addition'}},
#  {'input': 'What is 82 + 63?',
#   'target': 145,
#   'metadata': {'x': 82, 'y': 63, 'type': 'two_digit_addition'}},
#  {'input': 'What is 97 + 81?',
#   'target': 178,
#   'metadata': {'x': 97, 'y': 81, 'type': 'two_digit_addition'}},
#  {'input': 'What is 95 + 31?',
#   'target': 126,
#   'metadata': {'x': 95, 'y': 31, 'type': 'two_digit_addition'}},
#  {'input': 'What is 35 + 85?',
#   'target': 120,
#   'metadata': {'x': 35, 'y': 85, 'type': 'two_digit_addition'}},
#  {'input': 'What is 31 + 15?',
#   'target': 46,
#   'metadata': {'x': 31, 'y': 15, 'type': 'two_digit_addition'}},
#  {'input': 'What is 69 + 81?',
#   'target': 150,
#   'metadata': {'x': 69, 'y': 81, 'type': 'two_digit_addition'}},
#  {'input': 'What is 96 + 92?',
#   'target': 188,
#   'metadata': {'x': 96, 'y': 92, 'type': 'two_digit_addition'}},
#  {'input': 'What is 20 + 78?',
#   'target': 98,
#   'metadata': {'x': 20, 'y': 78, 'type': 'two_digit_addition'}},
#  {'input': 'What is 85 + 72?',
#   'target': 157,
#   'metadata': {'x': 85, 'y': 72, 'type': 'two_digit_addition'}},
#  {'input': 'What is 82 + 84?',
#   'target': 166,
#   'metadata': {'x': 82, 'y': 84, 'type': 'two_digit_addition'}},
#  {'input': 'What is 49 + 13?',
#   'target': 62,
#   'metadata': {'x': 49, 'y': 13, 'type': 'two_digit_addition'}},
#  {'input': 'What is 50 + 27?',
#   'target': 77,
#   'metadata': {'x': 50, 'y': 27, 'type': 'two_digit_addition'}},
#  {'input': 'What is 20 + 21?',
#   'target': 41,
#   'metadata': {'x': 20, 'y': 21, 'type': 'two_digit_addition'}},
#  {'input': 'What is 72 + 54?',
#   'target': 126,
#   'metadata': {'x': 72, 'y': 54, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 76?',
#   'target': 134,
#   'metadata': {'x': 58, 'y': 76, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 66?',
#   'target': 124,
#   'metadata': {'x': 58, 'y': 66, 'type': 'two_digit_addition'}},
#  {'input': 'What is 17 + 85?',
#   'target': 102,
#   'metadata': {'x': 17, 'y': 85, 'type': 'two_digit_addition'}},
#  {'input': 'What is 49 + 23?',
#   'target': 72,
#   'metadata': {'x': 49, 'y': 23, 'type': 'two_digit_addition'}},
#  {'input': 'What is 82 + 75?',
#   'target': 157,
#   'metadata': {'x': 82, 'y': 75, 'type': 'two_digit_addition'}},
#  {'input': 'What is 14 + 27?',
#   'target': 41,
#   'metadata': {'x': 14, 'y': 27, 'type': 'two_digit_addition'}},
#  {'input': 'What is 11 + 34?',
#   'target': 45,
#   'metadata': {'x': 11, 'y': 34, 'type': 'two_digit_addition'}},
#  {'input': 'What is 18 + 73?',
#   'target': 91,
#   'metadata': {'x': 18, 'y': 73, 'type': 'two_digit_addition'}},
#  {'input': 'What is 56 + 97?',
#   'target': 153,
#   'metadata': {'x': 56, 'y': 97, 'type': 'two_digit_addition'}},
#  {'input': 'What is 76 + 64?',
#   'target': 140,
#   'metadata': {'x': 76, 'y': 64, 'type': 'two_digit_addition'}},
#  {'input': 'What is 55 + 14?',
#   'target': 69,
#   'metadata': {'x': 55, 'y': 14, 'type': 'two_digit_addition'}},
#  {'input': 'What is 16 + 64?',
#   'target': 80,
#   'metadata': {'x': 16, 'y': 64, 'type': 'two_digit_addition'}},
#  {'input': 'What is 10 + 13?',
#   'target': 23,
#   'metadata': {'x': 10, 'y': 13, 'type': 'two_digit_addition'}},
#  {'input': 'What is 29 + 88?',
#   'target': 117,
#   'metadata': {'x': 29, 'y': 88, 'type': 'two_digit_addition'}},
#  {'input': 'What is 50 + 73?',
#   'target': 123,
#   'metadata': {'x': 50, 'y': 73, 'type': 'two_digit_addition'}},
#  {'input': 'What is 46 + 25?',
#   'target': 71,
#   'metadata': {'x': 46, 'y': 25, 'type': 'two_digit_addition'}},
#  {'input': 'What is 43 + 18?',
#   'target': 61,
#   'metadata': {'x': 43, 'y': 18, 'type': 'two_digit_addition'}},
#  {'input': 'What is 78 + 26?',
#   'target': 104,
#   'metadata': {'x': 78, 'y': 26, 'type': 'two_digit_addition'}},
#  {'input': 'What is 43 + 97?',
#   'target': 140,
#   'metadata': {'x': 43, 'y': 97, 'type': 'two_digit_addition'}},
#  {'input': 'What is 62 + 50?',
#   'target': 112,
#   'metadata': {'x': 62, 'y': 50, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 79?',
#   'target': 137,
#   'metadata': {'x': 58, 'y': 79, 'type': 'two_digit_addition'}},
#  {'input': 'What is 32 + 66?',
#   'target': 98,
#   'metadata': {'x': 32, 'y': 66, 'type': 'two_digit_addition'}},
#  {'input': 'What is 87 + 60?',
#   'target': 147,
#   'metadata': {'x': 87, 'y': 60, 'type': 'two_digit_addition'}},
#  {'input': 'What is 49 + 22?',
#   'target': 71,
#   'metadata': {'x': 49, 'y': 22, 'type': 'two_digit_addition'}},
#  {'input': 'What is 32 + 94?',
#   'target': 126,
#   'metadata': {'x': 32, 'y': 94, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 36?',
#   'target': 94,
#   'metadata': {'x': 58, 'y': 36, 'type': 'two_digit_addition'}},
#  {'input': 'What is 47 + 61?',
#   'target': 108,
#   'metadata': {'x': 47, 'y': 61, 'type': 'two_digit_addition'}},
#  {'input': 'What is 57 + 72?',
#   'target': 129,
#   'metadata': {'x': 57, 'y': 72, 'type': 'two_digit_addition'}},
#  {'input': 'What is 32 + 67?',
#   'target': 99,
#   'metadata': {'x': 32, 'y': 67, 'type': 'two_digit_addition'}},
#  {'input': 'What is 49 + 93?',
#   'target': 142,
#   'metadata': {'x': 49, 'y': 93, 'type': 'two_digit_addition'}},
#  {'input': 'What is 24 + 23?',
#   'target': 47,
#   'metadata': {'x': 24, 'y': 23, 'type': 'two_digit_addition'}},
#  {'input': 'What is 51 + 55?',
#   'target': 106,
#   'metadata': {'x': 51, 'y': 55, 'type': 'two_digit_addition'}},
#  {'input': 'What is 71 + 45?',
#   'target': 116,
#   'metadata': {'x': 71, 'y': 45, 'type': 'two_digit_addition'}},
#  {'input': 'What is 91 + 52?',
#   'target': 143,
#   'metadata': {'x': 91, 'y': 52, 'type': 'two_digit_addition'}},
#  {'input': 'What is 21 + 20?',
#   'target': 41,
#   'metadata': {'x': 21, 'y': 20, 'type': 'two_digit_addition'}},
#  {'input': 'What is 96 + 21?',
#   'target': 117,
#   'metadata': {'x': 96, 'y': 21, 'type': 'two_digit_addition'}},
#  {'input': 'What is 94 + 34?',
#   'target': 128,
#   'metadata': {'x': 94, 'y': 34, 'type': 'two_digit_addition'}},
#  {'input': 'What is 18 + 37?',
#   'target': 55,
#   'metadata': {'x': 18, 'y': 37, 'type': 'two_digit_addition'}},
#  {'input': 'What is 64 + 48?',
#   'target': 112,
#   'metadata': {'x': 64, 'y': 48, 'type': 'two_digit_addition'}},
#  {'input': 'What is 79 + 64?',
#   'target': 143,
#   'metadata': {'x': 79, 'y': 64, 'type': 'two_digit_addition'}},
#  {'input': 'What is 45 + 66?',
#   'target': 111,
#   'metadata': {'x': 45, 'y': 66, 'type': 'two_digit_addition'}},
#  {'input': 'What is 96 + 46?',
#   'target': 142,
#   'metadata': {'x': 96, 'y': 46, 'type': 'two_digit_addition'}},
#  {'input': 'What is 23 + 46?',
#   'target': 69,
#   'metadata': {'x': 23, 'y': 46, 'type': 'two_digit_addition'}},
#  {'input': 'What is 84 + 29?',
#   'target': 113,
#   'metadata': {'x': 84, 'y': 29, 'type': 'two_digit_addition'}},
#  {'input': 'What is 94 + 62?',
#   'target': 156,
#   'metadata': {'x': 94, 'y': 62, 'type': 'two_digit_addition'}},
#  {'input': 'What is 63 + 38?',
#   'target': 101,
#   'metadata': {'x': 63, 'y': 38, 'type': 'two_digit_addition'}},
#  {'input': 'What is 91 + 13?',
#   'target': 104,
#   'metadata': {'x': 91, 'y': 13, 'type': 'two_digit_addition'}},
#  {'input': 'What is 36 + 47?',
#   'target': 83,
#   'metadata': {'x': 36, 'y': 47, 'type': 'two_digit_addition'}},
#  {'input': 'What is 52 + 52?',
#   'target': 104,
#   'metadata': {'x': 52, 'y': 52, 'type': 'two_digit_addition'}},
#  {'input': 'What is 23 + 30?',
#   'target': 53,
#   'metadata': {'x': 23, 'y': 30, 'type': 'two_digit_addition'}},
#  {'input': 'What is 18 + 60?',
#   'target': 78,
#   'metadata': {'x': 18, 'y': 60, 'type': 'two_digit_addition'}},
#  {'input': 'What is 41 + 60?',
#   'target': 101,
#   'metadata': {'x': 41, 'y': 60, 'type': 'two_digit_addition'}},
#  {'input': 'What is 62 + 72?',
#   'target': 134,
#   'metadata': {'x': 62, 'y': 72, 'type': 'two_digit_addition'}},
#  {'input': 'What is 58 + 67?',
#   'target': 125,
#   'metadata': {'x': 58, 'y': 67, 'type': 'two_digit_addition'}},
#  {'input': 'What is 62 + 68?',
#   'target': 130,
#   'metadata': {'x': 62, 'y': 68, 'type': 'two_digit_addition'}},
#  {'input': 'What is 64 + 38?',
#   'target': 102,
#   'metadata': {'x': 64, 'y': 38, 'type': 'two_digit_addition'}},
#  {'input': 'What is 31 + 80?',
#   'target': 111,
#   'metadata': {'x': 31, 'y': 80, 'type': 'two_digit_addition'}},
#  {'input': 'What is 40 + 58?',
#   'target': 98,
#   'metadata': {'x': 40, 'y': 58, 'type': 'two_digit_addition'}},
#  {'input': 'What is 27 + 48?',
#   'target': 75,
#   'metadata': {'x': 27, 'y': 48, 'type': 'two_digit_addition'}},
#  {'input': 'What is 57 + 65?',
#   'target': 122,
#   'metadata': {'x': 57, 'y': 65, 'type': 'two_digit_addition'}},
#  {'input': 'What is 56 + 42?',
#   'target': 98,
#   'metadata': {'x': 56, 'y': 42, 'type': 'two_digit_addition'}},
#  {'input': 'What is 95 + 55?',
#   'target': 150,
#   'metadata': {'x': 95, 'y': 55, 'type': 'two_digit_addition'}},
#  ...]
